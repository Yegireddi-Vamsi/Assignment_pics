# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('Tiger.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
img1 = mpimg.imread('Black_Lab.jfif')
img1plot = plt.imshow(img1)
plt.show()
