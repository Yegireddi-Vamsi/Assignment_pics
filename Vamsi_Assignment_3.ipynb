# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread("Walking_tiger.jpg")
imgplot = plt.imshow(image)
plt.show()

# %%
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('Walking_tiger.jpg')

R, G, B = img[:,:,0], img[:,:,1], img[:,:,2]
imgGray = 0.2989 * R + 0.5870 * G + 0.1140 * B
plt.imshow(imgGray, cmap='gray')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
  
image = mpimg.imread('Walking_tiger.jpg')
plt.title("Output image")
  
hsv = matplotlib.colors.rgb_to_hsv(image)
plt.imshow(hsv)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
pip install OpenCV-python
# Out:
# Requirement already satisfied: OpenCV-python in c:\users\u1137735\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\u1137735\anaconda3\lib\site-packages (from OpenCV-python) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
gvn_image = cv2.imread("Walking_tiger.jpg")
gvn_image = cv2.cvtColor(gvn_image, cv2.COLOR_BGR2RGB)
grayscle_image = cv2.cvtColor(gvn_image, cv2.COLOR_BGR2GRAY)
invertd_image = cv2.bitwise_not(grayscle_image)
smooth_image = cv2.GaussianBlur(invertd_image, (21, 21),sigmaX=0, sigmaY=0)

# %%
pencil_skecth = cv2.divide(grayscle_image, 255 - smooth_image, scale=255)
plt.imshow(pencil_skecth, cmap="gray")
plt.title("Output Pencil Sketch Image")
plt.show()
